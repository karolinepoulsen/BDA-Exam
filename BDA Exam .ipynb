# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt 
import seaborn as sns
from collections import Counter 
import datetime
import json
import requests

# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt 
import seaborn as sns
from collections import Counter 
import datetime
import json
import requests

# %%
from PIL import Image

# %%
df = pd.read_csv("wishdata.csv",;,)
df.head()
# Out:
#   File "<ipython-input-15-d0e897c261a2>", line 1
#     df = pd.read_csv("wishdata.csv",;,)
#                                     ^
# SyntaxError: invalid syntax

# %%
df.dropna(inplace = True) 
df.isnull().sum() #droping null values 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 62 entries, 39 to 1558
# Data columns (total 43 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   title                         62 non-null     object
#  1   title_orig                    62 non-null     object
#  2   price                         62 non-null     float64
#  3   retail_price                  62 non-null     int64
#  4   currency_buyer                62 non-null     object
#  5   units_sold                    62 non-null     int64
#  6   uses_ad_boosts                62 non-null     int64
#  7   rating                        62 non-null     float64
#  8   rating_count                  62 non-null     int64
#  9   rating_five_count             62 non-null     float64
#  10  rating_four_count             62 non-null     float64
#  11  rating_three_count            62 non-null     float64
# ...

# %%
df.describe()
# Out:
#            price  retail_price    units_sold  uses_ad_boosts     rating  \
# count  62.000000     62.000000     62.000000       62.000000  62.000000
# mean    8.692097     23.112903   4590.322581        0.451613   3.750000
# std     3.482595     41.826380   6423.259723        0.501716   0.391005
# min     1.860000      2.000000    100.000000        0.000000   2.670000
# 25%     7.000000      6.000000    325.000000        0.000000   3.430000
# 50%     8.000000      8.500000   1000.000000        0.000000   3.755000
# 75%    11.000000     17.750000   5000.000000        1.000000   4.082500
# max    19.000000    250.000000  20000.000000        1.000000   4.520000
#
#        rating_count  rating_five_count  rating_four_count  rating_three_count  \
# count     62.000000          62.000000          62.000000           62.000000
# mean    1086.870968         513.338710         214.241935          157.161290
# std     2031.467744         951.455192         403.185784          303.729452
# ...

# %%
## Describing non-numerical values in dataframe
df.describe(include = ['O'])
# Out:
#                                                     title  \
# count                                                  62
# unique                                                 62
# top     Été Nouveau 2020 Mode Femmes Mince Longue Robe...
# freq                                                    1
#
#                                                title_orig currency_buyer  \
# count                                                  62             62
# unique                                                 62              1
# top     Women's Summer Fashion Spaghetti Strap Floral ...            EUR
# freq                                                    1             62
#
#                                                      tags product_color  \
# count                                                  62            62
# unique                                                 62            20
# top     Summer,Plus Size,Floral print,Tank,Tops,Spaghe...         black
# ...

# %%
## Showing correlation between variables
df.corr()
# Out:
#                                  price  retail_price  units_sold  \
# price                         1.000000      0.368893    0.334535
# retail_price                  0.368893      1.000000    0.344639
# units_sold                    0.334535      0.344639    1.000000
# uses_ad_boosts               -0.142036     -0.134492   -0.008287
# rating                        0.333311      0.076362    0.137118
# rating_count                  0.318680      0.285149    0.845857
# rating_five_count             0.353136      0.273410    0.831185
# rating_four_count             0.324609      0.296697    0.840940
# rating_three_count            0.280241      0.300993    0.852219
# rating_two_count              0.243502      0.280985    0.820608
# rating_one_count              0.222576      0.249155    0.781268
# badges_count                  0.141970      0.150871    0.011157
# badge_local_product                NaN           NaN         NaN
# ...

# %%
 Counter(" ".join(df["title"]).split()).most_common(50)
# Out:
# [('Robe', 30),
#  ('de', 29),
#  ('à', 23),
#  ('Femmes', 21),
#  ("d'été", 20),
#  ('Casual', 19),
#  ('manches', 19),
#  ('Mode', 18),
#  ('robe', 18),
#  ('Plus', 16),
#  ('Taille', 15),
#  ('Pantalon', 14),
#  ('taille', 13),
#  ('Summer', 12),
#  ('pour', 12),
#  ('sans', 11),
#  ('femmes', 11),
#  ('bain', 11),
#  ('Sans', 10),
#  ('Débardeur', 10),
#  ('Fashion', 10),
#  ('Dress', 10),
#  ('Manches', 9),
#  ('en', 9),
#  ('Women', 8),
#  ('courtes', 8),
#  ('Shorts', 8),
#  ('mode', 8),
#  ('Spaghetti', 7),
#  ('Strap', 7),
#  ('New', 7),
#  ('col', 7),
#  ('décontracté', 7),
#  ('Été', 7),
#  ('imprimé', 7),
#  ('2019', 7),
#  ('bretelles', 7),
#  ('Beach', 7),
#  ('Size', 7),
#  ("D'été", 6),
#  ('Mini', 6),
#  ('La', 6),
#  ('Sexy', 6),
#  ('Femme', 6),
#  ('la', 6),
#  ('et', 6),
#  ('Pants', 6),
#  ('Loose', 6),
#  ('plage', 6),
#  ('maillot', 6)]

# %%
Counter(" ".join(df["tags"]).split()).most_common(50)
# Out:
# [('Summer,Plus', 9),
#  ("dress,Women's", 8),
#  ("pants,Women's", 6),
#  ('&', 6),
#  ("top,Women's", 5),
#  ('Fashion,Plus', 5),
#  ('S', 4),
#  ('Fashion,Sleeveless', 4),
#  ('dress,beach', 4),
#  ('summer', 3),
#  ('dress,Women', 3),
#  ('Fashion,Women', 3),
#  ('Fashion,Long', 3),
#  ('top,tank', 3),
#  ('tops', 3),
#  ('sleeve', 3),
#  ('Women', 3),
#  ('dress', 3),
#  ('waist,Casual', 3),
#  ('dress,Round', 2),
#  ('slim', 2),
#  ('dress,maxi', 2),
#  ('Size,women', 2),
#  ('dresses,Evening', 2),
#  ('Dress,Dress,slim,casual', 2),
#  ('dresses,Mini', 2),
#  ('dresses,casual', 2),
#  ('dress,slim', 2),
#  ('dress,Shorts,Waist,short', 2),
#  ('dress,Slim', 2),
#  ("Fit,Women's", 2),
#  ('Fashion,camouflage,Sleeveless', 2),
#  ('dress,t,women', 2),
#  ('dress,long', 2),
#  ('Shorts,high', 2),
#  ('crop', 2),
#  ('for', 2),
#  ('women', 2),
#  ("neck,Women's", 2),
#  ('Sleeve', 2),
#  ('Fashion', 2),
#  ('bathing', 2),
#  ('Strap,tank', 2),
#  ('Strap,beach', 2),
# ...

# %%
#MOST SOLD PRODUCTS - Top 3
most_sold_product = df['units_sold'].idxmax()
print("Prodcut with highest sales irrespective of price: \n")
print(df.iloc[most_sold_product].head())
print('\n')
response1 = requests.get(df[df['units_sold'] == 100000].product_picture.tolist()[0]) 

#printing the thumbnail of that prodcuts
Image.open(BytesIO(response1.content))
# Out:
# Prodcut with highest sales irrespective of price:
#
# title             2018 New Fashion Women's Tops Sexy Strappy Sle...
# title_orig        2018 New Fashion Women's Tops Sexy Strappy Sle...
# price                                                           5.0
# retail_price                                                     25
# currency_buyer                                                  EUR
# Name: 17, dtype: object
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x7FFA5FACDAC0>
